# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
# %pwd
os.chdir('..')
# %pwd
# Out:
# '/mnt/c/Users/u0124144/Documents/Tsyganenko'

# %%
from DA.preprocess import read_and_parse
from DA.domain import get_results

# %%
grid, B, _, _, Bt = read_and_parse('model/TA15/ref_output/OUT00.DAT')
grid, cor_ext, cor_magn, field, variance = get_results('model/TA15/output', [0], [0])
# Out:
# Parsed model/T89/ref_output/OUT00.DAT
# model/T89/output
# Parsed model/T89/output/OUT01.DAT
# Parsed model/T89/output/OUT02.DAT
# Parsed model/T89/output/OUT03.DAT
# Parsed model/T89/output/OUT04.DAT
# Parsed model/T89/output/OUT05.DAT
# Parsed model/T89/output/OUT06.DAT
# Parsed model/T89/output/OUT07.DAT
# Parsed model/T89/output/OUT08.DAT
# Parsed model/T89/output/OUT09.DAT

# %%
variance['Bx']
# Out:
# array([[ 0.18481786,  0.18538087,  0.18594801, ..., 41.65320243,
#         41.24981126, 40.75372776],
#        [ 0.18538278,  0.18595608,  0.18653356, ..., 43.13032977,
#         42.75093691, 42.27814609],
#        [ 0.18593785,  0.18652141,  0.18710918, ..., 44.854622  ,
#         44.50557175, 44.06236609],
#        ...,
#        [ 0.0578189 ,  0.05878668,  0.05980132, ..., 20.15500828,
#         21.53803055, 23.0791154 ],
#        [ 0.05754699,  0.05851421,  0.05949527, ..., 24.70044022,
#         26.3698721 , 28.2257288 ],
#        [ 0.05727804,  0.0582424 ,  0.0592227 , ..., 30.01157306,
#         32.01091885, 34.22822271]])

# %%
strm = plt.streamplot(grid[0], grid[2], field[0], field[2])

# %%
fig, ax = plt.subplots(1,1, figsize=(32,16))
plt.contourf(grid[0],grid[2],np.log(variance['Bx']))
# Out:
# /home/brecht/miniconda3/envs/aida/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log
#
# /home/brecht/miniconda3/envs/aida/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log

# %%
plt.imshow(B[2])
